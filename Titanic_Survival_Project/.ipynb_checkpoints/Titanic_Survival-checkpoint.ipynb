# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns

# %%
dataset = pd.read_csv('train.csv')

# %%
dataset
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
pd.set_option('max_columns', 12)
pd.set_option('max_rows', 900)

# %%
dataset.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
dataset.shape
# Out:
# (891, 11)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
person = {
    'first':'Tanmoy',
    'last':'Era',
    'email':'tanmoyera@gmail.com'
}

# %%
people = {
    'first' : ["anmoy","era","TAn"],
    'last':['LastN','last_Y','last_tan'],
    'email':['last@gmail.com','tan@gmail.com','era@gmail.com']
}

# %%
people['email']
# Out:
# ['last@gmail.com', 'tan@gmail.com', 'era@gmail.com']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first      last           email
# 0  anmoy     LastN  last@gmail.com
# 1    era    last_Y   tan@gmail.com
# 2    TAn  last_tan   era@gmail.com

# %%
df['email']
# Out:
# 0    last@gmail.com
# 1     tan@gmail.com
# 2     era@gmail.com
# Name: email, dtype: object

# %%
type(df.email)
# Out:
# pandas.core.series.Series

# %%
type(dataset.Fare)
# Out:
# pandas.core.series.Series

# %%
#Serise is the rows of a single column
# DataFrame 2-d since rows and colmns + Serise holo ekta column er row 1-d matrix or vector

# %%
dataset[['Fare','Sex']].head() # we are sending a list of columns to display them
# Out:
#                 Fare     Sex
# PassengerId
# 1             7.2500    male
# 2            71.2833  female
# 3             7.9250  female
# 4            53.1000  female
# 5             8.0500    male

# %%
type(dataset[['Sex','Fare']]) # Since we are sending not a single col rows but multiple col rows this is not serise type instead a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset.iloc[[0,1]]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
dataset.iloc[[0,2],[2,9]]
# Out:
#                                 Name Cabin
# PassengerId
# 1            Braund, Mr. Owen Harris   NaN
# 3             Heikkinen, Miss. Laina   NaN

# %%
dataset.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
dataset.loc[0] # loc er label eikhane zero, so zero label er row show korbe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-68ada0a3379b> in <module>
# ...

# %%
dataset.loc[[0,1],['Fare','Sex']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-882a9b1bab24> in <module>
# ----> 1 dataset.loc[[0,1],['Fare','Sex']]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1065         # ugly hack for GH #836
#    1066         if self._multi_take_opportunity(tup):
# -> 1067             return self._multi_take(tup)
#    1068
# ...

# %%
dataset.loc[[0,1],['PassengerId','Pclass','Name']]

# %%
dataset.shape

# %%
dataset.columns

# %%
dataset['Sex']

# %%
dataset.loc[0:3,'Pclass':'Fare']

# %%
dataset['Sex'] = dataset['Sex'].map({'male':1,'female':0})

# %%
dataset['Sex'].isnull().any()

# %%
df

# %%
df['email']

# %%
df.set_index('email')

# %%
df

# %%
df.set_index('email',inplace = True)

# %%
df

# %%
df.index

# %%
df.loc['last@gmail.com','last']

# %%
df.iloc[0]

# %%
df.reset_index(inplace = True)

# %%
df

# %%
dataset.head()

# %%
dataset.set_index('PassengerId', inplace = True)

# %%
dataset.head()

# %%
dataset.reset_index(inplace = True)

# %%
dataset.loc[10, 'Name']

# %%
dataset.sort_index()

# %%
filt = dataset['Sex'] == 'male'

# %%
dataset[filt].info()

# %%
dataset.loc[filt, 'Age']

# %%
dataset.head()

# %%
filt = (dataset['Age'] < 30 )

# %%
dataset.loc[filt, ['Age','Sex','Name']]

# %%
dataset.loc[filt,'Sex']

# %%
dataset.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
ages = (dataset['Age']>60) & (dataset['Sex']== 'male')

# %%
dataset.loc[ages]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 34                  0       2                 Wheadon, Mr. Edward H  male
# 55                  0       1        Ostby, Mr. Engelhart Cornelius  male
# 97                  0       1             Goldschmidt, Mr. George B  male
# 117                 0       3                  Connors, Mr. Patrick  male
# 171                 0       1             Van der hoef, Mr. Wyckoff  male
# 253                 0       1             Stead, Mr. William Thomas  male
# 281                 0       3                      Duane, Mr. Frank  male
# 327                 0       3             Nysveen, Mr. Johan Hansen  male
# 439                 0       1                     Fortune, Mr. Mark  male
# 457                 0       1             Millet, Mr. Francis Davis  male
# 494                 0       1               Artagaveytia, Mr. Ramon  male
# ...

# %%
dataset.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
dataset.loc[ages,['Sex','Name','Fare']]
# Out:
#               Sex                                  Name      Fare
# PassengerId
# 34           male                 Wheadon, Mr. Edward H   10.5000
# 55           male        Ostby, Mr. Engelhart Cornelius   61.9792
# 97           male             Goldschmidt, Mr. George B   34.6542
# 117          male                  Connors, Mr. Patrick    7.7500
# 171          male             Van der hoef, Mr. Wyckoff   33.5000
# 253          male             Stead, Mr. William Thomas   26.5500
# 281          male                      Duane, Mr. Frank    7.7500
# 327          male             Nysveen, Mr. Johan Hansen    6.2375
# 439          male                     Fortune, Mr. Mark  263.0000
# 457          male             Millet, Mr. Francis Davis   26.5500
# 494          male               Artagaveytia, Mr. Ramon   49.5042
# 546          male          Nicholson, Mr. Arthur Ernest   26.0000
# 556          male                    Wright, Mr. George   26.5500
# ...

# %%
dataset.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
ages = [10,22,15,35,2]
filt = (dataset['Age'].isin(ages)) & (dataset['Sex'] == 'male')

# %%
dataset.loc[filt,'Age']
# Out:
# PassengerId
# 1      22.0
# 5      35.0
# 8       2.0
# 17      2.0
# 21     35.0
# 61     22.0
# 81     22.0
# 113    22.0
# 213    22.0
# 226    22.0
# 244    22.0
# 288    22.0
# 321    22.0
# 341     2.0
# 353    15.0
# 364    35.0
# 374    22.0
# 396    22.0
# 479    22.0
# 522    22.0
# 554    22.0
# 589    22.0
# 591    35.0
# 605    35.0
# 615    35.0
# 702    35.0
# 738    35.0
# 813    35.0
# 820    10.0
# 825     2.0
# 848    35.0
# Name: Age, dtype: float64

# %%
dataset.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
filt = dataset['Name'].str.contains('Mr', na= False)

# %%
dataset.loc[filt]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 9                   1       3
# 10                  1       2
# 13                  0       3
# 14                  0       3
# 16                  1       2
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 24                  1       1
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 30                  0       3
# 32                  1       1
# 34                  0       2
# 35                  0       1
# 36                  0       1
# 37                  1       3
# 38                  0       3
# 41                  0       3
# 42                  0       2
# ...

# %%
dataset['Sex'].head()
# Out:
# PassengerId
# 1      male
# 2    female
# 3    female
# 4    female
# 5      male
# Name: Sex, dtype: object

# %%
filt = (dataset['Sex']=='female')

# %%
filt = (dataset['Sex']=='male')
def filterf(filt):
    if filt == 'male':
        return 1
    elif filt == 'female':
        return 0
filterf('filt')

# %%
filt = (dataset['Sex']=='male')

# %%
filterf('filt')
# Out:
# 0

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def update_Sex(Sex):
    if Sex == 'male':
        return 1
    elif Sex == 'female':
        return 0

# %%
dataset['Sex'] = dataset['Sex'].apply(update_Sex)

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset['Sex'] = dataset['Sex'].map({'male':1,'female':0})

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
